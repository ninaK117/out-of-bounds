# %%
import pandas as pd
import seaborn as sns
from bs4 import BeautifulSoup
from scipy import stats
from sklearn import preprocessing
# SOURCES:
# https://stackoverflow.com/questions/53189494/apply-beautifulsoup-function-to-pandas-dataframe
# https://stackoverflow.com/questions/20297317/python-dataframe-pandas-drop-column-using-int
# Data Cleaning Notebook from Week 2 
# https://stackoverflow.com/questions/17383094/how-can-i-map-true-false-to-1-0-in-a-pandas-dataframe
# https://stackoverflow.com/questions/39885359/beautifulsoup-decompose
# https://stackoverflow.com/questions/26414913/normalize-columns-of-pandas-data-frame
# https://stackoverflow.com/questions/8080890/initialize-dict-with-keys-values-from-two-list

def has_tag(df, cols, tag):
    df_code = pd.DataFrame() 
    
    for c in cols:
        code = df[c].apply(lambda text: BeautifulSoup(text, 'html.parser').find_all(tag))
        col_name = c + '_HAS_CODE'
        
        code = (code.str.len() > 0).astype(int).rename(col_name).to_frame()
        df_code = pd.concat([df_code,code], axis=1)

    return df_code


def decompose_html(text, tag):   
    soup = BeautifulSoup(text, 'html.parser')
    code_tags = soup.findAll(tag)

    for code in code_tags:
        code.decompose()
    
    return str(soup)


def alter_col_text(df, cols, tag):   
    for c in cols:
        df[c] = df[c].apply(lambda text: decompose_html(text,tag))
        df[c] = df[c].apply(lambda text: BeautifulSoup(text, 'html.parser').text)
        df[c] = df[c].str.replace('\n',' ', regex=True)
    return df

df = pd.read_csv('data_5000.csv',header=0)
values = {'QUESTION_BODY': '', 'ACCEPTED_ANSWER_BODY': ''}
df.fillna(value = values)

cols = ['QUESTION_TITLE',
        'QUESTION_BODY',
        'ACCEPTED_ANSWER_BODY',
        'QUESTION_SCORE',
        'ANSWER_SCORE',
        'QUESTION_VIEWS',
        'ANSWER_COMMENT_COUNT',
        'ANSWER_REPUTATION']

tag = 'code'

body_cols = cols[1:3]
df = pd.concat([df,has_tag(df, body_cols, tag)], axis=1)
df = alter_col_text(df, body_cols, 'code')

# %%
def fill_nan_columns(df, columns):
    for column in columns:
        df[column] = df[column].fillna(0)
    return df
   
    
def normalize_columns(df, cols):
    for c in cols:
        min_max_scaler = preprocessing.MinMaxScaler()
        c_scaled = min_max_scaler.fit_transform(df[c].to_frame().values)
        df[c] = pd.DataFrame(c_scaled)
    return df
        

def remove_outliers(df, columns):
    for column in columns:
        lower = df[column].quantile(0.05)
        upper = df[column].quantile(0.95)
        df = df[df[column] >= lower]
        df = df[df[column] <= upper]
    return df

quant_cols = cols[3:]
print(quant_cols)
df = fill_nan_columns(df, quant_cols)
df = remove_outliers(df, quant_cols)
df = normalize_columns(df, quant_cols)
df = fill_nan_columns(df, quant_cols)
sns.pairplot(df[quant_cols])
df.to_csv('data.csv')
# Out:
# ['QUESTION_SCORE', 'ANSWER_SCORE', 'QUESTION_VIEWS', 'ANSWER_COMMENT_COUNT', 'ANSWER_REPUTATION']

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import KFold
#print(df.head())

# Regression on quantitative data
kf = KFold(n_splits=10, random_state=0, shuffle=True)
lasso = Lasso(alpha=0.005)
# Predict each of the following features using every other feature as its predictors

all_predictors = quant_cols + ['QUESTION_BODY_HAS_CODE', 'ACCEPTED_ANSWER_BODY_HAS_CODE']
for column in all_predictors:
    train_score_sum = 0
    test_score_sum = 0
    coeff_sums = {}
    count = 0
    feature = column
    predictors = [x for x in all_predictors if x != column]
    for predictor in predictors:
        coeff_sums[predictor] = 0.0
    print('feature: ', feature)
    for train_index, test_index in kf.split(df):
        x_train = df[predictors].iloc[train_index]
        y_train = df[feature].iloc[train_index]
        x_test = df[predictors].iloc[test_index]
        y_test = df[feature].iloc[test_index]

        lasso.fit(x_train, y_train)

        train_score_sum += lasso.score(x_train, y_train)
        test_score_sum += lasso.score(x_test, y_test)
        count += 1
        
        i = 0
        for predictor in predictors:
            coeff_sums[predictor] += lasso.coef_[i]
            i += 1

        #print('coefficients: ', lasso.coef_)
    
    print('average train score for ', feature, ': ', train_score_sum/count)
    print('average test score for ', feature, ': ', test_score_sum/count)
    print('coefficients: ')
    for predictor in predictors:
        print(predictor, ': ', coeff_sums[predictor]/count)
    print()
# Out:
# feature:  QUESTION_SCORE
# average train score for  QUESTION_SCORE :  0.28584523861174943
# average test score for  QUESTION_SCORE :  0.27762879365318155
# coefficients:
# ANSWER_SCORE :  0.23336464415890323
# QUESTION_VIEWS :  0.07796986238290819
# ANSWER_COMMENT_COUNT :  0.015717732511557458
# ANSWER_REPUTATION :  0.019356649206603967
# QUESTION_BODY_HAS_CODE :  0.0
# ACCEPTED_ANSWER_BODY_HAS_CODE :  0.0
#
# feature:  ANSWER_SCORE
# average train score for  ANSWER_SCORE :  0.32893702245037143
# average test score for  ANSWER_SCORE :  0.3232556943778233
# coefficients:
# QUESTION_SCORE :  0.5989683724434317
# QUESTION_VIEWS :  0.04694549114415901
# ANSWER_COMMENT_COUNT :  0.037616276407759816
# ANSWER_REPUTATION :  0.17841229520390728
# QUESTION_BODY_HAS_CODE :  0.0
# ACCEPTED_ANSWER_BODY_HAS_CODE :  0.0
#
# feature:  QUESTION_VIEWS
# average train score for  QUESTION_VIEWS :  0.08951639520710021
# average test score for  QUESTION_VIEWS :  0.08200061104880026
# coefficients:
# QUESTION_SCORE :  0.10850224865918348
# ANSWER_SCORE :  0.050748351192232144
# ANSWER_COMMENT_COUNT :  0.0
# ANSWER_REPUTATION :  0.0
# QUESTION_BODY_HAS_CODE :  0.0
# ACCEPTED_ANSWER_BODY_HAS_CODE :  0.0
#
# feature:  ANSWER_COMMENT_COUNT
# average train score for  ANSWER_COMMENT_COUNT :  0.13719821775901156
# average test score for  ANSWER_COMMENT_COUNT :  0.13342800765608026
# coefficients:
# QUESTION_SCORE :  0.04516046160572272
# ANSWER_SCORE :  0.06471907837979832
# QUESTION_VIEWS :  0.0
# ANSWER_REPUTATION :  0.12802053851162698
# QUESTION_BODY_HAS_CODE :  0.0
# ACCEPTED_ANSWER_BODY_HAS_CODE :  0.0
#
# feature:  ANSWER_REPUTATION
# average train score for  ANSWER_REPUTATION :  0.20511964792927478
# average test score for  ANSWER_REPUTATION :  0.1980330169052329
# coefficients:
# QUESTION_SCORE :  0.016652459031873613
# ANSWER_SCORE :  0.4061475564459435
# QUESTION_VIEWS :  0.0
# ANSWER_COMMENT_COUNT :  0.40687536890085385
# QUESTION_BODY_HAS_CODE :  0.0
# ACCEPTED_ANSWER_BODY_HAS_CODE :  0.0
#
# feature:  QUESTION_BODY_HAS_CODE
# average train score for  QUESTION_BODY_HAS_CODE :  0.1008005322574598
# average test score for  QUESTION_BODY_HAS_CODE :  0.0973979448923952
# coefficients:
# QUESTION_SCORE :  0.0
# ANSWER_SCORE :  0.0
# QUESTION_VIEWS :  0.0
# ANSWER_COMMENT_COUNT :  0.0
# ANSWER_REPUTATION :  0.0
# ACCEPTED_ANSWER_BODY_HAS_CODE :  0.26824137754933164
#
# feature:  ACCEPTED_ANSWER_BODY_HAS_CODE
# average train score for  ACCEPTED_ANSWER_BODY_HAS_CODE :  0.10080053225745982
# average test score for  ACCEPTED_ANSWER_BODY_HAS_CODE :  0.09129117794183583
# coefficients:
# QUESTION_SCORE :  0.0
# ANSWER_SCORE :  0.0
# QUESTION_VIEWS :  0.0
# ANSWER_COMMENT_COUNT :  0.0
# ANSWER_REPUTATION :  0.0
# QUESTION_BODY_HAS_CODE :  0.2232874458790682

# %%
print(df.columns)
# Out:
# Index(['QUESTION_TITLE', 'QUESTION_BODY', 'ACCEPTED_ANSWER_BODY',
#        'QUESTION_SCORE', 'QUESTION_VIEWS', 'ANSWER_SCORE',
#        'ANSWER_COMMENT_COUNT', 'ANSWER_REPUTATION', 'QUESTION_BODY_HAS_CODE',
#        'ACCEPTED_ANSWER_BODY_HAS_CODE'],
#       dtype='object')

# %%
answer_scores = pd.cut(df['ANSWER_SCORE'],4, labels=False, duplicates='drop').__array__()
question_scores = pd.cut(df['QUESTION_SCORE'],6, labels=False, duplicates='drop').__array__()

# answer_keys = ['poor','fair','good','excellent']
# question_keys = ['very bad', 'poor','fair','good','very good', 'excellent']

df['ANSWER_QUALITY'] = answer_scores
df['QUESTION_QUALITY'] = question_scores
